# %%
from jetracer.camera_utils import JetRacerCamera

camera = JetRacerCamera('training')
camera.start()

# %%
from jetracer.camera_utils import release_cam, JetRacerCamera
import time

release_cam()
time.sleep(3)

camera = JetRacerCamera('training')
camera.start()

# %%
from jetracer.camera_utils import JetRacerCamera

camera = JetRacerCamera('inference')
camera.start()

img = camera.read()

car.steering = 0.0
car.throttle = 0.0

camera.stop()

# %%
import gc
import time
import inspect

def release_all_cameras():
    frame = inspect.currentframe().f_back
    caller_globals = frame.f_globals

    camera_vars = []
    for name in list(caller_globals.keys()):
        try:
            obj = caller_globals[name]
            if (hasattr(obj, 'running') or hasattr(obj, 'cap') or 'camera' in str(type(obj)).lower()):
                camera_vars.append(name)
        except:
            pass

    for name in camera_vars:
        try:
            obj = caller_globals[name]
            if hasattr(obj, 'running'):
                obj.running = False
            if hasattr(obj, 'stop'):
                obj.stop()
            if hasattr(obj, 'cap') and hasattr(obj.cap, 'release'):
                obj.cap.release()
            del caller_globals[name]
        except:
            pass

    gc.collect()
    time.sleep(3)

def quick_camera_test():
    from jetcam.csi_camera import CSICamera
    cam = CSICamera(width=640, height=480, capture_fps=21)
    cam.running = True
    time.sleep(2)
    img = cam.value
    cam.running = False
    del cam
    return img is not None

def safe_camera_create(camera_class, *args, **kwargs):
    release_all_cameras()
    try:
        return camera_class(*args, **kwargs)
    except:
        return None

def release_cam():
    release_all_cameras()

def test_cam():
    return quick_camera_test()
